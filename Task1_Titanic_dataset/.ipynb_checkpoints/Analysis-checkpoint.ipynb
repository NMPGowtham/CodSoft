# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('Dataset/Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
features = ["Survived","Pclass","Age","SibSp","Parch","Fare"]

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.drop_duplicates(inplace =True)

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(9, 6))
axes = axes.flatten()
for ax, feature in zip(axes, features):
    ax.hist(df[feature], bins=10, color='blue', alpha=0.7)
    ax.set_title(feature)
    ax.set_xlabel(feature)
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(9, 6))
axes = axes.flatten()
for ax, feature in zip(axes, features):
    sns.boxplot(df[feature] , ax = ax)
    #ax.boxplot(df[feature])
    ax.set_title(feature)

plt.tight_layout()
plt.show()

# %%
df[features[2]].fillna(df[features[2]].mean(),inplace = True)
df[features[2]]
# Out:
# C:\Users\ROJA\AppData\Local\Temp\ipykernel_36844\2276509093.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[features[2]].fillna(df[features[2]].mean(),inplace = True)
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df["Embarked"].fillna("U", inplace=True)
# Out:
# C:\Users\ROJA\AppData\Local\Temp\ipykernel_36844\1004859557.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Embarked"].fillna("U", inplace=True)

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         4
# dtype: int64

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', 'U'], dtype=object)

# %%
df.shape
# Out:
# (891, 12)

# %%
updated_features = ["Survived","Pclass","Age","SibSp","Parch","Fare","Embarked","Sex"]

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(9, 6))
axes = axes.flatten()
for ax, feature in zip(axes, updated_features):
    sns.histplot(df[feature], kde=True, ax=ax)
    ax.set_title(feature)
    ax.set_xlabel(feature)
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    median_val = df[column].median()
    df[column] = np.where((df[column] < lower_bound) | (df[column] > upper_bound), median_val, df[column])
    return df

# %%
updated_df = remove_outliers(df,"Age")

# %%
updated_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   28.940388    0.523008
# std     257.353842    0.486592    0.836071    9.800230    1.102743
# min       1.000000    0.000000    1.000000    3.000000    0.000000
# 25%     223.500000    0.000000    2.000000   23.750000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   33.000000    1.000000
# max     891.000000    1.000000    3.000000   54.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
updated_df["Fare"] = np.log1p(updated_df["Fare"])
updated_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   28.940388    0.523008
# std     257.353842    0.486592    0.836071    9.800230    1.102743
# min       1.000000    0.000000    1.000000    3.000000    0.000000
# 25%     223.500000    0.000000    2.000000   23.750000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   33.000000    1.000000
# max     891.000000    1.000000    3.000000   54.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594    2.962246
# std      0.806057    0.969048
# min      0.000000    0.000000
# 25%      0.000000    2.187218
# 50%      0.000000    2.737881
# 75%      0.000000    3.465736
# max      6.000000    6.240917

# %%
def Gender2bin(data):
    if data == "male":
        return 0
    if data == "female":
        return 1

# %%
def City2bin(data):
    if data == "C":
        return 0
    if data == "Q":
        return 1
    if data == "S":
        return 2
    if data == "U":
        return 3

# %%
temp = updated_df.copy()
temp["Embarked"] = temp["Embarked"].apply(City2bin)
updated_df = temp
updated_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
temp = updated_df.copy()
temp["Sex"] = temp["Sex"].apply(Gender2bin)
updated_df = temp

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(9, 6))
axes = axes.flatten()

for ax, feature in zip(axes, updated_features):
    mean_val = updated_df[feature].mean()
    sns.histplot(updated_df[feature], kde=True, ax=ax)
    ax.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
    ax.set_title(feature)

plt.tight_layout()
plt.show()

# %%
updated_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.352413   28.940388
# std     257.353842    0.486592    0.836071    0.477990    9.800230
# min       1.000000    0.000000    1.000000    0.000000    3.000000
# 25%     223.500000    0.000000    2.000000    0.000000   23.750000
# 50%     446.000000    0.000000    3.000000    0.000000   29.699118
# 75%     668.500000    1.000000    3.000000    1.000000   33.000000
# max     891.000000    1.000000    3.000000    1.000000   54.000000
#
#             SibSp       Parch        Fare    Embarked
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.523008    0.381594    2.962246    1.538721
# std      1.102743    0.806057    0.969048    0.794231
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    2.187218    1.000000
# ...

# %%
final_df = updated_df[updated_features].copy()
final_df
# Out:
#      Survived  Pclass        Age  SibSp  Parch      Fare  Embarked  Sex
# 0           0       3  22.000000      1      0  2.110213         2    0
# 1           1       1  38.000000      1      0  4.280593         0    1
# 2           1       3  26.000000      0      0  2.188856         2    1
# 3           1       1  35.000000      1      0  3.990834         2    1
# 4           0       3  35.000000      0      0  2.202765         2    0
# ..        ...     ...        ...    ...    ...       ...       ...  ...
# 886         0       2  27.000000      0      0  2.639057         2    0
# 887         1       1  19.000000      0      0  3.433987         2    1
# 888         0       3  29.699118      1      2  3.196630         2    1
# 889         1       1  26.000000      0      0  3.433987         0    0
# 890         0       3  32.000000      0      0  2.169054         1    0
#
# [891 rows x 8 columns]

# %%
final_df.to_csv('Dataset/cleaned_data.csv')
